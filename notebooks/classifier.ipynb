# %%
import os
import sys
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import random_split, Subset, DataLoader

sys.path.append('../src/spectrogram')

from autoencoder_vit import DinoV2Autoencoder
from autoencoders import ResNetAutoEncoder
from data_loader import SpectogramDataset, ConstilationDataset

# %%
class DinoClassifier(nn.Module):
    def __init__(self, num_classes, freeze_encoder=False):
        super().__init__()
        # Instantiate the autoencoder to access its encoder part
        autoencoder = DinoV2Autoencoder(freeze_encoder=freeze_encoder)
        # autoencoder = ResNetAutoEncoder(arch='resnet34',
        #         batch_size=32,
        #         num_workers=1,
        #         eval_step=5)
        # Load pretrained weights if a path is provided
        # self.pretrained_path = '../exp/dino_autoencoder.pth'
        self.pretrained_path = '../exp/resnet_autoencoder.pth'
        if hasattr(self, 'pretrained_path') and self.pretrained_path is not None:
            checkpoint = torch.load(self.pretrained_path, map_location='cpu')
            autoencoder.load_state_dict(checkpoint, strict=False)
        self.encoder = autoencoder.encoder
        
        # DINO ViT-B/8 has a latent dimension of 768
        latent_dim = 768
        # latent_dim = 512

        # Add a pooling layer to convert the feature map to a vector
        self.pool = nn.AdaptiveAvgPool2d((1, 1))
       
        
        # Define a classification head
        self.classifier_head = nn.Sequential(
            nn.LayerNorm(latent_dim),
            nn.Linear(latent_dim, num_classes)
        )

    def forward(self, x):
        # The encoder returns the CLS token features
        features = self.encoder(x)
        # Pass features to the classification head
        # features = self.pool(features)
        # features = torch.flatten(features, 1)
    
        output = self.classifier_head(features)
        return output
    
def topk_accuracy(output, target, k=3):
    """Computes the top-k accuracy."""
    with torch.no_grad():
        batch_size = target.size(0)

        _, pred = output.topk(k, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
        return correct_k.item()

# %%
torch.cuda.empty_cache()  # Clear CUDA cache to avoid memory issues
# --- Configuration ---
# Adjust these paths to point to your dataset
BASE_DATA_PATH = '../data/own/unlabeled_10k/train' # Example path
CLASSES = ['OOK', '4ASK', '8ASK', 'OQPSK', 'CPFSK', 'GFSK', '4PAM', 'DQPSK', '16PAM', 'GMSK']

# Hyperparameters
NUM_EPOCHS = 100
LEARNING_RATE = 1e-4
BATCH_SIZE = 32
NUM_WORKERS = 4 # Adjust based on your system
EVAL_STEP = 5   # Evaluate on validation set every 5 epochs

# Define the transformation to apply to the spectrogram images
# The models expect a certain input size, e.g., 224x224 for ViT.
TRANSFORM = transforms.Compose([
    transforms.Resize((96, 96)), # Resizing to 96x96 as seen in your decoder architectures
    transforms.ToTensor()
])

# 2. Prepare Dataset and DataLoaders
# Instantiate the full dataset
full_dataset = ConstilationDataset(
    dataset_path=BASE_DATA_PATH,
    classes=CLASSES,
    transform=TRANSFORM
)

# Split dataset into training, validation, and test sets
train_size = int(0.8 * len(full_dataset))
val_size = int(0.1 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# 3. Initialize Model, Loss, and Optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DinoClassifier(num_classes=len(CLASSES), freeze_encoder=False).to(device)

# Loss function for multi-class classification
criterion = nn.CrossEntropyLoss()

# Optimizer (only training the classifier head)
optimizer = optim.AdamW(model.classifier_head.parameters(), lr=LEARNING_RATE)

print("Setup complete. Starting training...")
# Out:
# Using cache found in /home/woreom/.cache/torch/hub/facebookresearch_dino_main
# Setup complete. Starting training...

# %%
# 4. Training and Evaluation Loop
for epoch in range(NUM_EPOCHS):
    # --- Training Phase ---
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    
    train_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{NUM_EPOCHS}, Train Loss: {train_loss:.4f}")

    # --- Validation Phase ---
    if (epoch + 1) % EVAL_STEP == 0:
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                topk_correct_val += topk_accuracy(outputs, labels, k=3)
        
        val_accuracy = 100 * correct / total
        val_topk_accuracy = 100 * topk_correct_val / total
        print(f"Validation Loss: {val_loss/len(val_loader):.4f}, Validation Accuracy: {val_accuracy:.2f}%, Top-3 Accuracy: {val_topk_accuracy:.2f}%")


print("\nTraining finished. Evaluating on the test set...")

# 5. Final Evaluation on Test Set
model.eval()
test_correct = 0
topk_correct_test = 0
test_total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()
        topk_correct_test += topk_accuracy(outputs, labels, k=3)

test_accuracy = 100 * test_correct / test_total
test_topk_accuracy = 100 * topk_correct_test / test_total
print(f"Final Test Accuracy: {test_accuracy:.2f}%")
print(f"Final Test Top-3 Accuracy: {test_topk_accuracy:.2f}%")
# Out:
# Epoch 1/100, Train Loss: 1.5470
# Epoch 2/100, Train Loss: 1.0056
# Epoch 3/100, Train Loss: 0.8533
# Epoch 4/100, Train Loss: 0.7871
# Epoch 5/100, Train Loss: 0.7510
# Validation Loss: 0.7251, Validation Accuracy: 62.85%
# Epoch 6/100, Train Loss: 0.7283
# Epoch 7/100, Train Loss: 0.7128
# Epoch 8/100, Train Loss: 0.6992
# Epoch 9/100, Train Loss: 0.6901
# Epoch 10/100, Train Loss: 0.6825
# Validation Loss: 0.6625, Validation Accuracy: 66.55%
# Epoch 11/100, Train Loss: 0.6759
# Epoch 12/100, Train Loss: 0.6706
# Epoch 13/100, Train Loss: 0.6645
# Epoch 14/100, Train Loss: 0.6611
# Epoch 15/100, Train Loss: 0.6580
# Validation Loss: 0.6482, Validation Accuracy: 67.50%
# Epoch 16/100, Train Loss: 0.6546
# Epoch 17/100, Train Loss: 0.6504
# Epoch 18/100, Train Loss: 0.6479
# Epoch 19/100, Train Loss: 0.6452
# Epoch 20/100, Train Loss: 0.6436
# Validation Loss: 0.6315, Validation Accuracy: 66.95%
# Epoch 21/100, Train Loss: 0.6405
# Epoch 22/100, Train Loss: 0.6393
# Epoch 23/100, Train Loss: 0.6365
# Epoch 24/100, Train Loss: 0.6357
# Epoch 25/100, Train Loss: 0.6332
# Validation Loss: 0.6318, Validation Accuracy: 66.00%
# Epoch 26/100, Train Loss: 0.6308
# Epoch 27/100, Train Loss: 0.6295
# Epoch 28/100, Train Loss: 0.6283
# Epoch 29/100, Train Loss: 0.6262
# Epoch 30/100, Train Loss: 0.6247
# Validation Loss: 0.6238, Validation Accuracy: 67.40%
# Epoch 31/100, Train Loss: 0.6228
# Epoch 32/100, Train Loss: 0.6225
# Epoch 33/100, Train Loss: 0.6217
# Epoch 34/100, Train Loss: 0.6210
# Epoch 35/100, Train Loss: 0.6192
# Validation Loss: 0.6194, Validation Accuracy: 66.45%
# Epoch 36/100, Train Loss: 0.6184
# Epoch 37/100, Train Loss: 0.6170
# Epoch 38/100, Train Loss: 0.6162
# Epoch 39/100, Train Loss: 0.6150
# Epoch 40/100, Train Loss: 0.6134
# Validation Loss: 0.6169, Validation Accuracy: 67.15%
# Epoch 41/100, Train Loss: 0.6131
# Epoch 42/100, Train Loss: 0.6115
# Epoch 43/100, Train Loss: 0.6126
# Epoch 44/100, Train Loss: 0.6105
# Epoch 45/100, Train Loss: 0.6094
# Validation Loss: 0.6055, Validation Accuracy: 68.35%
# Epoch 46/100, Train Loss: 0.6093
# Epoch 47/100, Train Loss: 0.6079
# Epoch 48/100, Train Loss: 0.6074
# Epoch 49/100, Train Loss: 0.6064
# Epoch 50/100, Train Loss: 0.6069
# Validation Loss: 0.6087, Validation Accuracy: 68.50%
# Epoch 51/100, Train Loss: 0.6050
# Epoch 52/100, Train Loss: 0.6038
# Epoch 53/100, Train Loss: 0.6050
# Epoch 54/100, Train Loss: 0.6043
# Epoch 55/100, Train Loss: 0.6025
# Validation Loss: 0.6023, Validation Accuracy: 68.85%
# Epoch 56/100, Train Loss: 0.6016
# Epoch 57/100, Train Loss: 0.6016
# Epoch 58/100, Train Loss: 0.6007
# Epoch 59/100, Train Loss: 0.6003
# Epoch 60/100, Train Loss: 0.5998
# Validation Loss: 0.5974, Validation Accuracy: 69.85%
# Epoch 61/100, Train Loss: 0.5987
# Epoch 62/100, Train Loss: 0.5996
# Epoch 63/100, Train Loss: 0.5988
# Epoch 64/100, Train Loss: 0.5975
# Epoch 65/100, Train Loss: 0.5980
# Validation Loss: 0.5974, Validation Accuracy: 69.40%
# Epoch 66/100, Train Loss: 0.5956
# Epoch 67/100, Train Loss: 0.5953
# Epoch 68/100, Train Loss: 0.5964
# Epoch 69/100, Train Loss: 0.5956
# Epoch 70/100, Train Loss: 0.5950
# Validation Loss: 0.5955, Validation Accuracy: 69.40%
# Epoch 71/100, Train Loss: 0.5948
# Epoch 72/100, Train Loss: 0.5944
# Epoch 73/100, Train Loss: 0.5937
# Epoch 74/100, Train Loss: 0.5929
# Epoch 75/100, Train Loss: 0.5927
# Validation Loss: 0.5964, Validation Accuracy: 68.65%
# Epoch 76/100, Train Loss: 0.5921
# Epoch 77/100, Train Loss: 0.5921
# Epoch 78/100, Train Loss: 0.5916
# Epoch 79/100, Train Loss: 0.5914
# Epoch 80/100, Train Loss: 0.5903
# Validation Loss: 0.5927, Validation Accuracy: 69.10%
# Epoch 81/100, Train Loss: 0.5897
# Epoch 82/100, Train Loss: 0.5899
# Epoch 83/100, Train Loss: 0.5899
# Epoch 84/100, Train Loss: 0.5902
# Epoch 85/100, Train Loss: 0.5881
# Validation Loss: 0.6042, Validation Accuracy: 67.60%
# Epoch 86/100, Train Loss: 0.5887
# Epoch 87/100, Train Loss: 0.5878
# Epoch 88/100, Train Loss: 0.5871
# Epoch 89/100, Train Loss: 0.5875
# Epoch 90/100, Train Loss: 0.5871
# Validation Loss: 0.5930, Validation Accuracy: 69.60%
# Epoch 91/100, Train Loss: 0.5865
# Epoch 92/100, Train Loss: 0.5862
# Epoch 93/100, Train Loss: 0.5862
# Epoch 94/100, Train Loss: 0.5855
# Epoch 95/100, Train Loss: 0.5850
# Validation Loss: 0.6009, Validation Accuracy: 67.85%
# Epoch 96/100, Train Loss: 0.5861
# Epoch 97/100, Train Loss: 0.5854
# Epoch 98/100, Train Loss: 0.5837
# Epoch 99/100, Train Loss: 0.5840
# Epoch 100/100, Train Loss: 0.5840
# Validation Loss: 0.5886, Validation Accuracy: 69.90%
#
# Training finished. Evaluating on the test set...
# Final Test Accuracy: 65.75%

# %%
model = DinoClassifier(num_classes=len(CLASSES), freeze_encoder=False)
model.load_state_dict(torch.load('../exp/dino_classifier.pth'))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
test_correct = 0
topk_correct_test = 0
test_total = 0
topk=2

full_dataset = ConstilationDataset(
    dataset_path='../data/own/unlabeled_10k/test',
    classes=CLASSES,
    transform=TRANSFORM
)

test_loader = DataLoader(full_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)


with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()
        topk_correct_test += topk_accuracy(outputs, labels, k=topk)

test_accuracy = 100 * test_correct / test_total
test_topk_accuracy = 100 * topk_correct_test / test_total
print(f"Final Test Accuracy: {test_accuracy:.2f}%")
print(f"Final Test Top-{topk} Accuracy: {test_topk_accuracy:.2f}%")
# Out:
# Using cache found in /home/woreom/.cache/torch/hub/facebookresearch_dino_main
# Final Test Accuracy: 65.33%
# Final Test Top-2 Accuracy: 87.00%

# %%
from glob import glob
from PIL import Image
import json

topk = 7
model = DinoClassifier(num_classes=len(CLASSES), freeze_encoder=False)
model.load_state_dict(torch.load('../exp/dino_classifier.pth', map_location='cpu', weights_only=True))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

dataset_path='../data/own/unlabeled_10k/test'
noiseless_image_path = os.path.join(dataset_path, 'noiseLessImg')
noisy_image_path = os.path.join(dataset_path, 'noisyImg')
signal_images = glob(os.path.join(noiseless_image_path, '*.png'))
signal_images.extend(glob(os.path.join(noisy_image_path, '*.png')))


predictions = {}
with torch.no_grad():
    for image_path in signal_images:
        image = Image.open(image_path).convert("RGB")
        image = TRANSFORM(image).unsqueeze(0).to(device)
        outputs = model(image)
        # Get top 4 predictions
        probs, indices = torch.topk(outputs, topk, dim=1)

        # Convert indices to class names
        pred_classes = [CLASSES[i] for i in indices[0]]
        # Store predictions
        type_img = os.path.basename(os.path.dirname(image_path))
        file_name = os.path.basename(image_path)
        predictions[file_name] = predictions.get(file_name, {})
        predictions[file_name][type_img] = pred_classes


# Save predictions to a JSON file
with open(f'../data/own/unlabeled_10k/top{topk}_predictions.json', 'w') as f:
    json.dump(predictions, f, indent=4)

print(f"Top-{topk} predictions saved to top{topk}_predictions.json")
# Out:
# Using cache found in /home/woreom/.cache/torch/hub/facebookresearch_dino_main
# /tmp/ipykernel_5579/1850828141.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(self.pretrained_path, map_location='cpu')
# Top-7 predictions saved to top7_predictions.json

# %%
from scipy.spatial.distance import cdist
import numpy as np

# --- 1. Setup Model and Data ---
print("--- Setting up model and data for feature extraction ---")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the trained classifier model
model = DinoClassifier(num_classes=len(CLASSES), freeze_encoder=False) # Freeze encoder as we only need features
model.load_state_dict(torch.load('../exp/dino_classifier.pth', map_location=device, weights_only=True))
model.to(device)
model.eval()

# Load the full training dataset
# We need to modify the dataset to return file paths along with images and labels
class DatasetWithPath(ConstilationDataset):
    def __getitem__(self, idx):
        image, label = super().__getitem__(idx)
        path = self.signal_images[idx]
        return image, label, path

train_dataset = DatasetWithPath(
    dataset_path='../data/own/unlabeled_10k/train', # Using the training data path
    classes=CLASSES,
    transform=TRANSFORM
)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# --- 2. Extract Features for All Training Samples ---
print("--- Extracting features from all training samples ---")
features_by_class = {i: [] for i in range(len(CLASSES))}
paths_by_class = {i: [] for i in range(len(CLASSES))}

with torch.no_grad():
    for images, labels, paths in train_loader:
        images = images.to(device)
        # Use the model's encoder to get feature vectors
        # The forward pass of the encoder is what we need
        features = model.encoder(images)
        
        for i in range(len(labels)):
            label_idx = labels[i].item()
            features_by_class[label_idx].append(features[i].cpu().numpy())
            paths_by_class[label_idx].append(paths[i])

# --- 3. Calculate Class Centers (Centroids) ---
print("--- Calculating class centers ---")
class_centers = {}
for i in range(len(CLASSES)):
    if features_by_class[i]:
        class_features = np.array(features_by_class[i])
        class_centers[i] = np.mean(class_features, axis=0)

# --- 4. Find the Closest Sample to Each Center ---
print("--- Finding the closest sample to each class center ---")
closest_samples = {}
for i in range(len(CLASSES)):
    if i in class_centers:
        center = class_centers[i].reshape(1, -1)
        features = np.array(features_by_class[i])
        
        # Calculate Euclidean distance from each sample to the center
        distances = cdist(features, center, 'euclidean')
        
        # Find the index of the sample with the minimum distance
        closest_sample_index = np.argmin(distances)
        
        # Get the path of the closest sample
        closest_path = paths_by_class[i][closest_sample_index]
        closest_samples[CLASSES[i]] = closest_path

# --- 5. Print the Results ---
print("\n--- Closest Sample to the Center of Each Class ---")
for class_name, path in closest_samples.items():
    print(f"{class_name}: {path}")
# Out:
# --- Setting up model and data for feature extraction ---
# Using cache found in /home/woreom/.cache/torch/hub/facebookresearch_dino_main
# /tmp/ipykernel_93753/1850828141.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(self.pretrained_path, map_location='cpu')
# --- Extracting features from all training samples ---
# --- Calculating class centers ---
# --- Finding the closest sample to each class center ---
#
# --- Closest Sample to the Center of Each Class ---
# OOK: ../data/own/unlabeled_10k/train/noisyImg/OOK_2.17dB__0379_20250627_150438.png
# 4ASK: ../data/own/unlabeled_10k/train/noisyImg/4ASK_6.58dB__0216_20250627_150737.png
# 8ASK: ../data/own/unlabeled_10k/train/noiseLessImg/8ASK_7.10dB__0265_20250627_151057.png
# OQPSK: ../data/own/unlabeled_10k/train/noisyImg/OQPSK_6.17dB__0942_20250627_151545.png
# CPFSK: ../data/own/unlabeled_10k/train/noisyImg/CPFSK_5.11dB__0829_20250627_151906.png
# GFSK: ../data/own/unlabeled_10k/train/noisyImg/GFSK_3.57dB__0396_20250627_152112.png
# 4PAM: ../data/own/unlabeled_10k/train/noisyImg/4PAM_9.86dB__0954_20250627_152654.png
# DQPSK: ../data/own/unlabeled_10k/train/noisyImg/DQPSK_8.61dB__0739_20250627_152953.png
# 16PAM: ../data/own/unlabeled_10k/train/noisyImg/16PAM_-9.62dB__0681_20250627_153144.png
# GMSK: ../data/own/unlabeled_10k/train/noisyImg/GMSK_7.45dB__0839_20250627_155308.png

# %%
import pickle

# Assuming the pickle file is named 'train_data.pkl' and located in a 'data' directory
# Please adjust the path to your pickle file accordingly.
with open('../data/own/unlabeled_10k/test_noisySignal_5_4_data.pkl', 'rb') as f:
    train_data = pickle.load(f)

# Now, train_data contains the data from the pickle file.
# You can print it to verify
# print(train_data)
train_data.keys()
# Out:
# dict_keys(['signal_paths', 'signals', 'stats', 'discret_stats', 'labels', 'snrs', 'prompts', 'discret_prompts', 'old_prompts', 'old_discret_prompts', 'feature_names', 'scaler', 'discretizers', 'num_samples', 'num_features', '#classes', '#snr', 'k-top'])

# %%
i = 1
print(train_data['discret_prompts'][i], train_data['labels'][i])
print(len(train_data['old_prompts'][0]), len(train_data['labels']))
# Out:
# **ROLE:**
# You are an expert AI signal classifier specializing in wireless communication modulation schemes.
#
# **OBJECTIVE:**
# Your task is to classify the modulation scheme of a wireless signal based on its provided `KBinsDiscretizer` statistical features. You will use your domain knowledge of signal processing to interpret the features and select the correct classification from a predefined list.
#
# **CONTEXT:**
# The classification is based on the principle that moments and cumulants of a signal's I/Q components create a unique feature set. For instance, the fourth-order cumulant is a powerful differentiator between modulation formats like BPSK, QPSK, and various QAM schemes. The provided statistics are the features extracted from a signal after being processed by a `KBinsDiscretizer`, which quantifies the signal's distribution. Your analysis should map these statistical features to the most likely modulation scheme.
#
# **Signal Statistics:** snr: C, skewness: B, kurtosis: D, moment_0: A, moment_1: A, moment_2: A, moment_3: C, moment_4: A, moment_5: C, moment_6: A, moment_7: C, moment_8: A, moment_9: C, kstat_1: C, kstat_2: A, kstat_3: C, kstat_4: B, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['16PAM', '8ASK', '4PAM', '4ASK'].
# **Answer:** 16PAM
# **Signal Statistics:** snr: C, skewness: B, kurtosis: D, moment_0: A, moment_1: A, moment_2: A, moment_3: C, moment_4: A, moment_5: C, moment_6: A, moment_7: C, moment_8: A, moment_9: C, kstat_1: C, kstat_2: A, kstat_3: C, kstat_4: B, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['16PAM', '8ASK', '4PAM', '4ASK'].
# **Answer:** 8ASK
# **Signal Statistics:** snr: C, skewness: C, kurtosis: D, moment_0: A, moment_1: A, moment_2: A, moment_3: C, moment_4: A, moment_5: C, moment_6: A, moment_7: C, moment_8: A, moment_9: C, kstat_1: C, kstat_2: A, kstat_3: C, kstat_4: B, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['16PAM', '8ASK', '4PAM', '4ASK'].
# **Answer:** 4PAM
# **Signal Statistics:** snr: C, skewness: B, kurtosis: D, moment_0: A, moment_1: A, moment_2: A, moment_3: C, moment_4: A, moment_5: C, moment_6: A, moment_7: C, moment_8: A, moment_9: C, kstat_1: C, kstat_2: A, kstat_3: C, kstat_4: B, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['16PAM', '8ASK', '4PAM', '4ASK'].
# **Answer:** 4ASK
#
#
# **RESPONSE RULES:**
#
# 1.  **MANDATORY:** You **MUST** first use `<think>` tags to detail your step-by-step reasoning. Analyze the provided statistics, compare them to the known characteristics of each modulation type in the options list, and decide on the most probable classification.
# 2.  **MANDATORY:** After the closing `</think>` tag, you **MUST** provide only the final classification.
# 3.  The output **MUST** be a single entry, selected exclusively from the `CLASSIFICATION OPTIONS` list.
# 4.  There **MUST NOT** be any additional words, explanations, or introductory text in the final output (e.g., no "The classification is:").
#
# -----
#
# **TASK EXECUTION:**
#
# **Signal Statistics:** snr: C, skewness: B, kurtosis: D, moment_0: A, moment_1: A, moment_2: A, moment_3: C, moment_4: A, moment_5: C, moment_6: A, moment_7: C, moment_8: A, moment_9: C, kstat_1: E, kstat_2: A, kstat_3: C, kstat_4: B, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['16PAM', '8ASK', '4PAM', '4ASK'].
# **Answer:**
# Classify the signal based on the provided data and options, following all rules above. 16PAM
# 5385 2000

# %%
"""
### Instructions
    You are an expert quantitative analyst in wireless communication modulation.
    Based on your knowledge in wireless communication modulation and the detailed signal statistics provided below, determine the modulation type.
"""
# Out:
#   Cell In[11], line 1
#     """
#     ^
# SyntaxError: incomplete input

# %%
import os
import pickle

# with open('../data/own/unlabeled_10k/test_noiselessSignal_data.pkl', 'rb') as f:
#     noiseless_data = pickle.load(f)

# print(noiseless_data.keys())
N_BINS = 20
TOP_K = 5
NOISE_MODE = 'noisySignal'
file_name = '../data/own/unlabeled_10k/test/noisySignal/4ASK_-5.57dB__076_20250127_145624.npy'
with open(f'../data/own/unlabeled_10k/test_{NOISE_MODE}_{N_BINS}_{TOP_K}_data.pkl', 'rb') as f:
    noisy_data = pickle.load(f)

print(noisy_data.keys())

# Compare the prompts of two data (noiseless and noisy) for the same index

idx = noisy_data['signal_paths'].index(os.path.abspath(file_name))  # You can change this index to compare other samples

# idx = 0

# print("Noiseless prompt:")
# print(noiseless_data['prompts'][idx])
# print("\nNoisy prompt:")
# print(noisy_data['prompts'][idx])

# print("\nNoiseless discrete prompt:")
# print(noiseless_data['discret_prompts'][idx])
print("\nNoisy discrete prompt:")
print(noisy_data['discret_prompts'][idx])

# print("\nLabel (should be the same):")
# print(noiseless_data['labels'][idx], noisy_data['labels'][idx])


# Compare the number of tokens for discret_prompts with old_prompts

# import re

# from transformers import GPT2TokenizerFast

# # Initialize GPT-2 tokenizer (compatible with OpenAI GPT tokenization)
# gpt_tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")

# def count_tokens(text):
#     # Use GPT tokenizer to count tokens
#     return len(gpt_tokenizer.encode(text))

# idx = 0  # You can change this index to compare other samples

# print(len(noiseless_data['prompts'][idx]))
# print(len(noiseless_data['old_prompts'][idx]))
# print(len(noiseless_data['discret_prompts'][idx]))


# discret_prompt = noiseless_data['discret_prompts'][idx]
# old_prompt = noiseless_data['old_prompts'][idx]

# discret_tokens = count_tokens(discret_prompt)
# old_tokens = count_tokens(old_prompt)

# print(f"Number of tokens in discret_prompt: {discret_tokens}")
# print(f"Number of tokens in old_prompt: {old_tokens}")
# Out:
# dict_keys(['signal_paths', 'signals', 'stats', 'discret_stats', 'labels', 'snrs', 'prompts', 'discret_prompts', 'old_prompts', 'old_discret_prompts', 'feature_names', 'scaler', 'discretizers', 'num_samples', 'num_features', '#classes', '#snr', 'k-top'])
#
# Noisy discrete prompt:
# **ROLE:**
# You are an expert AI signal classifier specializing in wireless communication modulation schemes.
#
# **OBJECTIVE:**
# Your task is to classify the modulation scheme of a wireless signal based on its provided `KBinsDiscretizer` statistical features. You will use your domain knowledge of signal processing to interpret the features and select the correct classification from a predefined list.
#
# **CONTEXT:**
# The classification is based on the principle that moments and cumulants of a signal's I/Q components create a unique feature set. For instance, the fourth-order cumulant is a powerful differentiator between modulation formats like BPSK, QPSK, and various QAM schemes. The provided statistics are the features extracted from a signal after being processed by a `KBinsDiscretizer`, which quantifies the signal's distribution. Your analysis should map these statistical features to the most likely modulation scheme.
#
# **Signal Statistics:** snr: J, skewness: G, kurtosis: K, moment_0: A, moment_1: A, moment_2: A, moment_3: J, moment_4: A, moment_5: K, moment_6: A, moment_7: I, moment_8: A, moment_9: J, kstat_1: K, kstat_2: A, kstat_3: J, kstat_4: H, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['OQPSK', '4ASK', '4PAM', '8ASK', 'DQPSK'].
# **Answer:** OQPSK
# **Signal Statistics:** snr: J, skewness: G, kurtosis: P, moment_0: A, moment_1: A, moment_2: A, moment_3: J, moment_4: A, moment_5: K, moment_6: A, moment_7: I, moment_8: A, moment_9: J, kstat_1: K, kstat_2: A, kstat_3: J, kstat_4: H, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['OQPSK', '4ASK', '4PAM', '8ASK', 'DQPSK'].
# **Answer:** 4ASK
# **Signal Statistics:** snr: K, skewness: I, kurtosis: O, moment_0: A, moment_1: A, moment_2: A, moment_3: J, moment_4: A, moment_5: K, moment_6: A, moment_7: I, moment_8: A, moment_9: J, kstat_1: J, kstat_2: A, kstat_3: J, kstat_4: H, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['OQPSK', '4ASK', '4PAM', '8ASK', 'DQPSK'].
# **Answer:** 4PAM
# **Signal Statistics:** snr: J, skewness: F, kurtosis: P, moment_0: A, moment_1: A, moment_2: A, moment_3: J, moment_4: A, moment_5: K, moment_6: A, moment_7: I, moment_8: A, moment_9: J, kstat_1: L, kstat_2: A, kstat_3: J, kstat_4: H, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['OQPSK', '4ASK', '4PAM', '8ASK', 'DQPSK'].
# **Answer:** 8ASK
# **Signal Statistics:** snr: J, skewness: H, kurtosis: J, moment_0: A, moment_1: A, moment_2: A, moment_3: J, moment_4: A, moment_5: K, moment_6: A, moment_7: I, moment_8: A, moment_9: J, kstat_1: K, kstat_2: A, kstat_3: J, kstat_4: H, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['OQPSK', '4ASK', '4PAM', '8ASK', 'DQPSK'].
# **Answer:** DQPSK
#
#
# **RESPONSE RULES:**
#
# 1.  **MANDATORY:** You **MUST** first use `<think>` tags to detail your step-by-step reasoning. Analyze the provided statistics, compare them to the known characteristics of each modulation type in the options list, and decide on the most probable classification.
# 2.  **MANDATORY:** After the closing `</think>` tag, you **MUST** provide only the final classification.
# 3.  The output **MUST** be a single entry, selected exclusively from the `CLASSIFICATION OPTIONS` list.
# 4.  There **MUST NOT** be any additional words, explanations, or introductory text in the final output (e.g., no "The classification is:").
#
# -----
#
# **TASK EXECUTION:**
#
# **Signal Statistics:** snr: E, skewness: G, kurtosis: N, moment_0: A, moment_1: A, moment_2: A, moment_3: J, moment_4: A, moment_5: K, moment_6: A, moment_7: I, moment_8: A, moment_9: J, kstat_1: K, kstat_2: A, kstat_3: J, kstat_4: H, kstatvar_1: A, kstatvar_2: A,
# **Classification Options:** ['OQPSK', '4ASK', '4PAM', '8ASK', 'DQPSK'].
# **Answer:**
# Classify the signal based on the provided data and options, following all rules above.

# %%
noisy_data['signal_paths']
# Out:
# ['/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.08dB__058_20250127_145951.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.14dB__059_20250127_164735.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.16dB__076_20250127_145955.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.19dB__045_20250127_145948.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.20dB__091_20250127_145958.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.32dB__083_20250127_145957.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.34dB__059_20250127_145951.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.37dB__038_20250127_145947.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.58dB__095_20250127_164745.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.76dB__081_20250127_145956.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.83dB__011_20250127_145941.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.88dB__077_20250127_164740.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-0.89dB__044_20250127_145948.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-1.16dB__069_20250127_164738.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-1.26dB__039_20250127_164730.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-1.27dB__033_20250127_164729.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-1.33dB__012_20250127_145942.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-1.35dB__049_20250127_145949.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-1.50dB__066_20250127_164737.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-1.52dB__053_20250127_145950.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-1.63dB__089_20250127_145958.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-1.97dB__060_20250127_164736.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.03dB__020_20250127_164727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.06dB__049_20250127_164733.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.32dB__096_20250127_145959.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.34dB__099_20250127_150000.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.38dB__058_20250127_164735.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.52dB__009_20250127_145941.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.55dB__014_20250127_145942.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.56dB__015_20250127_145942.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.60dB__069_20250127_145954.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.74dB__013_20250127_145942.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-2.99dB__051_20250127_164733.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.16dB__026_20250127_164727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.28dB__051_20250127_145950.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.30dB__036_20250127_145947.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.31dB__056_20250127_145951.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.36dB__024_20250127_164726.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.38dB__005_20250127_145940.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.39dB__042_20250127_145948.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.45dB__065_20250127_164737.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.74dB__050_20250127_145949.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.88dB__004_20250127_164723.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-3.98dB__031_20250127_145946.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-4.01dB__060_20250127_145952.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-4.11dB__064_20250127_164737.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-4.17dB__009_20250127_164724.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-4.50dB__073_20250127_164739.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-4.65dB__027_20250127_145945.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-4.85dB__006_20250127_164723.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-5.01dB__075_20250127_145955.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-5.09dB__061_20250127_164736.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-5.11dB__085_20250127_164742.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-5.14dB__043_20250127_145948.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-5.19dB__030_20250127_164728.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-5.50dB__071_20250127_164738.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-5.57dB__092_20250127_145958.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-5.58dB__000_20250127_164722.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-5.62dB__081_20250127_164741.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-5.68dB__041_20250127_145948.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-6.33dB__066_20250127_145953.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-6.50dB__018_20250127_164726.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-6.53dB__021_20250127_164727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-6.81dB__078_20250127_145956.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-6.99dB__038_20250127_164730.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.00dB__021_20250127_145944.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.07dB__018_20250127_145943.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.09dB__035_20250127_145946.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.11dB__022_20250127_145944.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.12dB__076_20250127_164740.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.13dB__015_20250127_164726.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.13dB__098_20250127_164745.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.33dB__086_20250127_164742.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.35dB__055_20250127_145951.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.37dB__067_20250127_164737.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.43dB__048_20250127_145949.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.44dB__017_20250127_145943.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.46dB__079_20250127_164740.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.94dB__016_20250127_145943.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-7.99dB__098_20250127_150000.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.14dB__045_20250127_164732.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.17dB__080_20250127_164741.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.17dB__084_20250127_164742.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.29dB__087_20250127_145957.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.37dB__097_20250127_145959.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.42dB__074_20250127_164739.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.49dB__032_20250127_145946.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.52dB__064_20250127_145953.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.61dB__088_20250127_145958.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.72dB__068_20250127_145953.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-8.76dB__096_20250127_164745.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-9.03dB__084_20250127_145957.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-9.05dB__073_20250127_145955.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-9.28dB__023_20250127_164726.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-9.31dB__080_20250127_145956.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-9.47dB__042_20250127_164731.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-9.54dB__070_20250127_164738.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-9.55dB__022_20250127_164727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-9.65dB__032_20250127_164728.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_-9.79dB__024_20250127_145944.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_0.07dB__090_20250127_145958.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_0.09dB__000_20250127_145939.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_0.10dB__056_20250127_164734.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_0.27dB__008_20250127_164724.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_0.28dB__036_20250127_164729.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_0.28dB__085_20250127_145957.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_0.59dB__027_20250127_164727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_0.78dB__079_20250127_145956.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_0.79dB__008_20250127_145941.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_0.93dB__087_20250127_164743.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_1.24dB__010_20250127_145941.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_1.24dB__030_20250127_145945.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_1.34dB__028_20250127_145945.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_1.34dB__068_20250127_164738.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_1.50dB__097_20250127_164745.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_1.52dB__094_20250127_145959.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_1.62dB__095_20250127_145959.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_1.86dB__029_20250127_164728.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_1.97dB__013_20250127_164725.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_2.01dB__070_20250127_145954.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_2.07dB__035_20250127_164729.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_2.23dB__001_20250127_164722.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_2.30dB__037_20250127_164730.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_2.65dB__074_20250127_145955.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_2.70dB__062_20250127_145952.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_2.73dB__061_20250127_145952.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_2.83dB__099_20250127_164746.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_2.92dB__090_20250127_164743.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_3.01dB__071_20250127_145954.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_3.28dB__011_20250127_164725.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_3.32dB__093_20250127_145959.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_3.38dB__001_20250127_145939.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_3.38dB__089_20250127_164743.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_3.46dB__023_20250127_145944.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_3.63dB__047_20250127_164732.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_3.83dB__063_20250127_145952.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_3.84dB__003_20250127_145940.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_4.09dB__025_20250127_164727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_4.29dB__082_20250127_145956.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_4.31dB__091_20250127_164744.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_4.49dB__029_20250127_145945.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_4.65dB__006_20250127_145940.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_4.68dB__019_20250127_145943.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_4.70dB__039_20250127_145947.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_4.85dB__046_20250127_145949.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_4.94dB__046_20250127_164732.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_5.04dB__054_20250127_164734.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_5.43dB__044_20250127_164731.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_5.51dB__004_20250127_145940.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_5.52dB__034_20250127_164729.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_5.54dB__063_20250127_164736.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_5.76dB__053_20250127_164734.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_5.84dB__088_20250127_164743.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.03dB__003_20250127_164723.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.10dB__007_20250127_164724.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.13dB__075_20250127_164739.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.17dB__043_20250127_164731.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.24dB__072_20250127_145954.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.26dB__072_20250127_164739.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.29dB__065_20250127_145953.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.31dB__094_20250127_164744.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.43dB__016_20250127_164726.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.46dB__031_20250127_164728.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.74dB__057_20250127_164735.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.89dB__057_20250127_145951.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.96dB__033_20250127_145946.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.97dB__034_20250127_145946.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_6.99dB__067_20250127_145953.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.00dB__092_20250127_164744.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.01dB__047_20250127_145949.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.16dB__002_20250127_164722.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.28dB__093_20250127_164744.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.31dB__040_20250127_164730.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.37dB__020_20250127_145943.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.43dB__025_20250127_145944.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.51dB__019_20250127_164727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.69dB__083_20250127_164741.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.79dB__017_20250127_164726.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.80dB__054_20250127_145950.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_7.96dB__050_20250127_164733.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_8.16dB__002_20250127_145940.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_8.32dB__040_20250127_145947.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_8.55dB__010_20250127_164724.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_8.56dB__048_20250127_164732.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_8.73dB__007_20250127_145941.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_8.92dB__014_20250127_164725.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.03dB__005_20250127_164723.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.13dB__055_20250127_164734.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.38dB__012_20250127_164725.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.39dB__026_20250127_145944.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.40dB__077_20250127_145955.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.41dB__062_20250127_164736.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.51dB__082_20250127_164741.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.58dB__028_20250127_164727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.60dB__041_20250127_164731.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.63dB__086_20250127_145957.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.66dB__052_20250127_145950.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.76dB__037_20250127_145947.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.82dB__052_20250127_164733.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/16PAM_9.95dB__078_20250127_164740.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-0.17dB__081_20250127_164342.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-0.36dB__065_20250127_164336.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-0.49dB__093_20250127_145629.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-0.54dB__011_20250127_145603.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-0.59dB__061_20250127_164335.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-0.63dB__034_20250127_145610.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-0.80dB__066_20250127_145620.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-0.89dB__047_20250127_164330.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-0.94dB__080_20250127_164342.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.01dB__030_20250127_164324.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.11dB__075_20250127_164340.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.12dB__097_20250127_164347.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.20dB__021_20250127_164320.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.21dB__092_20250127_164345.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.21dB__096_20250127_164346.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.36dB__031_20250127_164324.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.51dB__086_20250127_145627.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.64dB__001_20250127_145600.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.66dB__071_20250127_145622.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.93dB__005_20250127_145602.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-1.99dB__036_20250127_164326.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-2.13dB__045_20250127_164329.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-2.34dB__041_20250127_145612.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-2.36dB__087_20250127_145627.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-2.43dB__047_20250127_145614.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-2.87dB__035_20250127_145611.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-2.91dB__056_20250127_145617.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-2.99dB__074_20250127_164340.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-3.01dB__054_20250127_164332.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-3.11dB__050_20250127_164331.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-3.31dB__019_20250127_145606.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-3.33dB__035_20250127_164326.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-3.36dB__076_20250127_164340.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-3.51dB__057_20250127_164333.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-3.64dB__001_20250127_164313.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-4.28dB__011_20250127_164317.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-4.49dB__091_20250127_145629.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-4.50dB__071_20250127_164339.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-4.53dB__081_20250127_145625.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-4.54dB__058_20250127_145618.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-4.75dB__031_20250127_145609.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-4.78dB__024_20250127_164322.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-4.87dB__041_20250127_164328.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.07dB__036_20250127_145611.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.11dB__027_20250127_164323.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.18dB__074_20250127_145623.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.25dB__016_20250127_164319.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.27dB__080_20250127_145625.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.30dB__059_20250127_164334.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.32dB__057_20250127_145617.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.37dB__067_20250127_164337.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.52dB__020_20250127_164320.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.53dB__032_20250127_164324.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.57dB__076_20250127_145624.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-5.78dB__023_20250127_145607.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-6.03dB__015_20250127_145605.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-6.13dB__000_20250127_164313.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-6.32dB__078_20250127_164341.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-6.35dB__069_20250127_164338.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-6.58dB__052_20250127_145616.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-6.61dB__088_20250127_145628.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-6.81dB__004_20250127_164314.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-6.87dB__068_20250127_145621.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-6.91dB__028_20250127_164323.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-6.95dB__002_20250127_164314.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.02dB__067_20250127_145621.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.18dB__013_20250127_164318.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.22dB__018_20250127_145605.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.24dB__032_20250127_145610.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.43dB__003_20250127_145601.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.47dB__015_20250127_164318.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.66dB__014_20250127_145604.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.74dB__073_20250127_145623.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.79dB__009_20250127_145603.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.93dB__069_20250127_145621.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-7.96dB__009_20250127_164316.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.15dB__093_20250127_164345.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.24dB__055_20250127_145617.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.30dB__028_20250127_145608.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.34dB__054_20250127_145617.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.38dB__073_20250127_164339.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.49dB__025_20250127_164322.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.61dB__095_20250127_145630.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.70dB__052_20250127_164332.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.72dB__094_20250127_164346.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.74dB__087_20250127_164343.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.76dB__038_20250127_145611.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.83dB__040_20250127_164327.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-8.84dB__002_20250127_145601.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.07dB__049_20250127_164331.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.16dB__098_20250127_145631.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.43dB__072_20250127_164339.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.46dB__027_20250127_145608.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.55dB__099_20250127_164347.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.57dB__000_20250127_145600.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.57dB__042_20250127_145613.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.74dB__065_20250127_145620.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.80dB__029_20250127_145609.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.82dB__085_20250127_164344.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.86dB__012_20250127_164317.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.94dB__059_20250127_145618.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_-9.96dB__008_20250127_145603.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.05dB__034_20250127_164325.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.09dB__029_20250127_164323.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.13dB__098_20250127_164347.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.23dB__044_20250127_145613.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.24dB__006_20250127_145602.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.32dB__056_20250127_164333.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.66dB__039_20250127_145612.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.66dB__049_20250127_145615.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.73dB__077_20250127_145624.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.80dB__038_20250127_164327.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.84dB__050_20250127_145615.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_0.90dB__013_20250127_145604.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_1.18dB__053_20250127_145616.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_1.33dB__090_20250127_164344.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_1.39dB__039_20250127_164327.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_1.46dB__051_20250127_164331.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_1.56dB__012_20250127_145604.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_1.66dB__084_20250127_145626.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_2.15dB__083_20250127_145626.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_2.59dB__033_20250127_145610.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_2.81dB__005_20250127_164315.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_2.86dB__077_20250127_164341.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_2.91dB__022_20250127_145607.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.15dB__064_20250127_145620.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.18dB__079_20250127_145625.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.36dB__094_20250127_145629.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.38dB__072_20250127_145622.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.47dB__058_20250127_164334.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.49dB__095_20250127_164346.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.67dB__017_20250127_164319.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.78dB__044_20250127_164329.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.93dB__043_20250127_164328.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.94dB__046_20250127_145614.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_3.95dB__025_20250127_145608.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.00dB__083_20250127_164343.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.05dB__062_20250127_164335.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.06dB__026_20250127_145608.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.09dB__091_20250127_164345.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.45dB__055_20250127_164333.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.45dB__082_20250127_164343.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.57dB__037_20250127_164326.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.61dB__068_20250127_164338.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.70dB__040_20250127_145612.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.76dB__003_20250127_164314.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_4.99dB__006_20250127_164315.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.11dB__082_20250127_145626.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.16dB__078_20250127_145624.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.17dB__063_20250127_164336.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.28dB__048_20250127_145615.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.29dB__046_20250127_164329.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.36dB__090_20250127_145628.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.58dB__018_20250127_164319.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.78dB__024_20250127_145607.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.83dB__037_20250127_145611.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.87dB__016_20250127_145605.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.88dB__045_20250127_145614.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_5.97dB__061_20250127_145619.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_6.06dB__008_20250127_164316.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_6.37dB__043_20250127_145613.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_6.55dB__089_20250127_145628.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_6.93dB__070_20250127_164338.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.13dB__096_20250127_145630.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.44dB__070_20250127_145622.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.45dB__019_20250127_164320.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.47dB__023_20250127_164321.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.52dB__085_20250127_145627.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.58dB__097_20250127_145630.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.67dB__007_20250127_164316.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.71dB__007_20250127_145602.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.88dB__014_20250127_164318.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.89dB__033_20250127_164325.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.92dB__020_20250127_145606.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.92dB__092_20250127_145629.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_7.97dB__053_20250127_164332.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_8.03dB__048_20250127_164330.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_8.20dB__022_20250127_164321.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_8.35dB__075_20250127_145623.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_8.37dB__010_20250127_145603.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_8.42dB__017_20250127_145605.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_8.68dB__060_20250127_164335.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_8.72dB__062_20250127_145619.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_8.98dB__060_20250127_145618.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.01dB__030_20250127_145609.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.01dB__064_20250127_164336.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.10dB__004_20250127_145601.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.16dB__088_20250127_164343.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.24dB__026_20250127_164322.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.28dB__086_20250127_164343.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.37dB__084_20250127_164343.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.45dB__010_20250127_164317.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.60dB__021_20250127_145606.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.63dB__099_20250127_145631.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.65dB__066_20250127_164337.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.68dB__063_20250127_145619.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.84dB__089_20250127_164344.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.89dB__079_20250127_164342.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.93dB__051_20250127_145616.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4ASK_9.94dB__042_20250127_164328.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-0.00dB__031_20250127_164618.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-0.02dB__002_20250127_145832.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-0.06dB__034_20250127_145843.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-0.09dB__042_20250127_164622.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-0.18dB__073_20250127_145856.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-0.30dB__046_20250127_164623.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-0.61dB__097_20250127_145904.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-0.80dB__044_20250127_164623.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-1.10dB__003_20250127_164607.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-1.19dB__084_20250127_164636.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-1.27dB__001_20250127_145832.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-1.29dB__083_20250127_145859.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-1.35dB__055_20250127_145850.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-1.39dB__017_20250127_164612.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-1.61dB__064_20250127_145853.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-1.97dB__033_20250127_164618.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.03dB__066_20250127_145853.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.09dB__091_20250127_145902.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.10dB__048_20250127_145847.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.10dB__068_20250127_145854.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.24dB__015_20250127_164612.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.33dB__058_20250127_145851.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.34dB__000_20250127_164606.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.43dB__027_20250127_145840.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.46dB__008_20250127_145834.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.55dB__007_20250127_145834.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.60dB__022_20250127_145839.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/4PAM_-2.79dB__095_20250127_145903.npy',
# ...
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-4.79dB__005_20250127_145727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-4.81dB__049_20250127_145741.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-5.09dB__091_20250127_145755.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-5.26dB__074_20250127_164519.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-5.47dB__036_20250127_145737.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-5.63dB__013_20250127_164455.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-5.80dB__049_20250127_164509.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-5.83dB__023_20250127_164459.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-5.91dB__093_20250127_164525.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-6.22dB__011_20250127_164454.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-6.22dB__024_20250127_164459.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-6.42dB__028_20250127_164501.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-6.61dB__043_20250127_164507.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-6.64dB__031_20250127_164502.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-6.74dB__050_20250127_145741.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-6.77dB__085_20250127_145753.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-7.58dB__043_20250127_145739.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-7.63dB__035_20250127_164503.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-7.74dB__025_20250127_145733.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-7.77dB__021_20250127_145732.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-7.83dB__098_20250127_164527.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-7.89dB__006_20250127_145727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.06dB__001_20250127_145725.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.12dB__077_20250127_145750.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.18dB__002_20250127_164451.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.21dB__015_20250127_164456.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.25dB__020_20250127_164458.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.28dB__061_20250127_145745.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.29dB__030_20250127_164502.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.55dB__039_20250127_145738.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.68dB__057_20250127_164512.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.88dB__009_20250127_145728.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-8.95dB__087_20250127_164523.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.01dB__017_20250127_145731.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.14dB__004_20250127_145726.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.31dB__027_20250127_145734.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.33dB__019_20250127_164457.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.39dB__034_20250127_164503.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.50dB__004_20250127_164452.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.50dB__028_20250127_145734.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.50dB__042_20250127_145739.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.53dB__038_20250127_164505.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.56dB__082_20250127_145752.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.74dB__045_20250127_164508.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.74dB__069_20250127_145748.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.80dB__088_20250127_145754.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.93dB__000_20250127_164450.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_-9.97dB__056_20250127_145743.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_0.05dB__005_20250127_164452.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_0.07dB__041_20250127_145738.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_0.12dB__097_20250127_164527.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_0.18dB__050_20250127_164510.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_0.30dB__032_20250127_164502.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_0.34dB__020_20250127_145732.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_0.41dB__052_20250127_164510.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_0.66dB__051_20250127_164510.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.00dB__033_20250127_164503.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.08dB__060_20250127_164513.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.19dB__026_20250127_164500.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.27dB__093_20250127_145756.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.36dB__026_20250127_145734.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.53dB__037_20250127_145737.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.67dB__046_20250127_164508.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.74dB__059_20250127_164513.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.75dB__047_20250127_164508.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.90dB__078_20250127_164519.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.97dB__080_20250127_164520.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_1.99dB__076_20250127_145750.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.13dB__096_20250127_145757.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.14dB__010_20250127_164454.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.15dB__019_20250127_145731.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.16dB__092_20250127_164525.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.31dB__090_20250127_164524.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.51dB__006_20250127_164452.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.55dB__037_20250127_164504.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.63dB__081_20250127_145752.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.64dB__009_20250127_164454.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.76dB__012_20250127_164455.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.81dB__042_20250127_164506.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.88dB__075_20250127_145750.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.89dB__051_20250127_145742.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_2.91dB__059_20250127_145744.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_3.02dB__053_20250127_164511.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_3.21dB__083_20250127_164521.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_3.22dB__067_20250127_145747.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_3.34dB__079_20250127_145751.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_3.54dB__075_20250127_164519.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_3.56dB__091_20250127_164524.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_4.01dB__029_20250127_145735.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_4.07dB__077_20250127_164519.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_4.11dB__024_20250127_145733.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_4.36dB__096_20250127_164526.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_4.41dB__095_20250127_145756.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_4.53dB__089_20250127_164524.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_4.56dB__022_20250127_145732.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_4.68dB__097_20250127_145757.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_4.71dB__080_20250127_145751.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_4.99dB__048_20250127_145741.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_5.19dB__084_20250127_145753.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_5.20dB__022_20250127_164459.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_5.22dB__003_20250127_164451.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_5.28dB__055_20250127_164511.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_5.28dB__068_20250127_145747.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_5.32dB__073_20250127_145749.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_5.35dB__014_20250127_164455.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_5.39dB__045_20250127_145740.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_5.80dB__061_20250127_164514.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_5.90dB__069_20250127_164517.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_6.06dB__054_20250127_145743.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_6.22dB__054_20250127_164511.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_6.32dB__008_20250127_164453.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_6.46dB__072_20250127_145749.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_6.47dB__079_20250127_164520.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_6.52dB__025_20250127_164500.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_6.58dB__052_20250127_145742.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_6.75dB__007_20250127_145727.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_6.95dB__070_20250127_164517.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_7.04dB__030_20250127_145735.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_7.06dB__083_20250127_145752.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_7.14dB__086_20250127_145753.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_7.26dB__094_20250127_145756.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_7.33dB__098_20250127_145757.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_7.42dB__033_20250127_145736.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_7.73dB__015_20250127_145730.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_7.74dB__071_20250127_164518.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_7.87dB__072_20250127_164518.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_8.10dB__071_20250127_145748.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_8.41dB__008_20250127_145728.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_8.48dB__029_20250127_164501.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_8.52dB__038_20250127_145737.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_8.70dB__092_20250127_145755.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_8.81dB__066_20250127_145747.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_8.91dB__001_20250127_164451.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_8.96dB__021_20250127_164458.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_8.98dB__014_20250127_145730.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_9.02dB__099_20250127_164528.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_9.22dB__035_20250127_145736.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_9.31dB__046_20250127_145740.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_9.66dB__010_20250127_145728.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_9.79dB__016_20250127_145730.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_9.87dB__040_20250127_164506.npy',
#  '/mnt/d/Rowan/discrete-llm-amc/data/own/unlabeled_10k/test/noisySignal/CPFSK_9.92dB__048_20250127_164509.npy',
#  ...]

# %%
with open('../data/own/unlabeled_10k/test_noisySignal_data.pkl', 'rb') as f:
    new_old_data = pickle.load(f)

print(len(new_old_data['discret_prompts'][idx]))
# Out:
# 3502

# %%
print(len(noisy_data['discret_prompts'][idx]))
# Out:
# 4119
